# %%
import numpy as np
import pandas as pd
import os 
# %matplotlib inline
#import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# C:\Users\ranam\AppData\Local\Temp\ipykernel_24548\2053032497.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# #load dataset

# %%
# load the data
DATASET_PATH = r'C:\Users\ranam\Documents\ML\projects\datasets'
def load_data (Credit_card_path = DATASET_PATH):
    csv_path = os.path.join(Credit_card_path,"creditcard.csv")
    return pd.read_csv(csv_path)

# load the head data
CreditCard = load_data()
CreditCard.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# ...

# %%
print(CreditCard.shape)
#summarize null values 
print(CreditCard.isnull().sum())
# Out:
# (284807, 31)
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
for col in CreditCard.columns:
    print(CreditCard[col].value_counts(ascending = True))
# Out:
# Time
# 86113.0      1
# 92548.0      1
# 92550.0      1
# 92554.0      1
# 92555.0      1
#             ..
# 3770.0      20
# 3767.0      21
# 68780.0     25
# 64947.0     26
# 163152.0    36
# Name: count, Length: 124592, dtype: int64
# V1
# -1.359807     1
# -1.911468     1
#  2.070666     1
# -0.740209     1
#  2.082579     1
#              ..
#  2.040211    53
#  1.302378    60
#  2.053311    62
#  2.055797    77
#  1.245674    77
# Name: count, Length: 275663, dtype: int64
# V2
# -0.072781     1
#  0.286228     1
# -0.087005     1
#  0.547351     1
# -0.094679     1
#              ..
# -0.146975    53
# -0.606529    60
#  0.089735    62
# -0.326668    77
#  0.166975    77
# Name: count, Length: 275663, dtype: int64
# V3
#  2.536347     1
#  0.612120     1
# -1.136060     1
# -1.445228     1
# -1.942331     1
#              ..
# -2.955934    53
# -0.681986    60
# -1.681836    62
# -2.752041    77
#  0.488306    77
# Name: count, Length: 275663, dtype: int64
# V4
# ...

# %%
CreditCard.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
list(CreditCard.columns)
# Out:
# ['Time',
#  'V1',
#  'V2',
#  'V3',
#  'V4',
#  'V5',
#  'V6',
#  'V7',
#  'V8',
#  'V9',
#  'V10',
#  'V11',
#  'V12',
#  'V13',
#  'V14',
#  'V15',
#  'V16',
#  'V17',
#  'V18',
#  'V19',
#  'V20',
#  'V21',
#  'V22',
#  'V23',
#  'V24',
#  'V25',
#  'V26',
#  'V27',
#  'V28',
#  'Amount',
#  'Class']

# %%
# check duplication 
CreditCard.duplicated().sum()
# Out:
# 1081

# %%
CreditCard.drop_duplicates(inplace=True)

# %%
CreditCard.describe()
# Out:
#                 Time             V1             V2             V3  \
# count  283726.000000  283726.000000  283726.000000  283726.000000
# mean    94811.077600       0.005917      -0.004135       0.001613
# std     47481.047891       1.948026       1.646703       1.508682
# min         0.000000     -56.407510     -72.715728     -48.325589
# 25%     54204.750000      -0.915951      -0.600321      -0.889682
# 50%     84692.500000       0.020384       0.063949       0.179963
# 75%    139298.000000       1.316068       0.800283       1.026960
# max    172792.000000       2.454930      22.057729       9.382558
#
#                   V4             V5             V6             V7  \
# count  283726.000000  283726.000000  283726.000000  283726.000000
# mean       -0.002966       0.001828      -0.001139       0.001801
# std         1.414184       1.377008       1.331931       1.227664
# min        -5.683171    -113.743307     -26.160506     -43.557242
# ...

# %%
CreditCard.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 283726 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    283726 non-null  float64
#  1   V1      283726 non-null  float64
#  2   V2      283726 non-null  float64
#  3   V3      283726 non-null  float64
#  4   V4      283726 non-null  float64
#  5   V5      283726 non-null  float64
#  6   V6      283726 non-null  float64
#  7   V7      283726 non-null  float64
#  8   V8      283726 non-null  float64
#  9   V9      283726 non-null  float64
#  10  V10     283726 non-null  float64
#  11  V11     283726 non-null  float64
#  12  V12     283726 non-null  float64
#  13  V13     283726 non-null  float64
#  14  V14     283726 non-null  float64
#  15  V15     283726 non-null  float64
#  16  V16     283726 non-null  float64
#  17  V17     283726 non-null  float64
#  18  V18     283726 non-null  float64
#  19  V19     283726 non-null  float64
# ...

# %% [markdown]
# **Visulization data**

# %%
CreditCard.hist(bins = 10,figsize=(20,15))
plt.show()

# %% [markdown]
# *note from the visualization (time ,  amount , class) not gaussion distribution*

# %%
counts = CreditCard["Class"].value_counts()
plt.pie(counts, labels= ['Normal(0)','fraud(1)'] ,autopct="%1.1f%%")
plt.title("Distribution by class (credit card fraud detection)")
plt.show()

# %% [markdown]
# # Spliting the dataset

# %%
x= CreditCard.drop(["Class"],axis =1)
y = CreditCard["Class"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test= train_test_split(x,y,test_size=.20 , random_state= 42)

# %% [markdown]
# **Data Preprocessing**

# %%
# scaling the data
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
for col in x.columns:
    x[col] = scaler.fit_transform(x[[col]])

# %%
y.shape
# Out:
# (283726,)

# %%
y_train.shape
# Out:
# (226980,)

# %%
y_test.shape
# Out:
# (56746,)

# %%
import seaborn as sns
cov_matrix = abs(x.cov())
plt.figure(figsize=(20, 20))
sns.heatmap(cov_matrix, annot=True, cmap='Greens', fmt='.2f', linewidths=.5)
plt.title('Covariance Matrix Heatmap')
plt.show()

# %%
y_train.shape
# Out:
# (226980,)

# %%
import warnings
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import GradientBoostingClassifier, AdaBoostClassifier, RandomForestClassifier
from sklearn.metrics import confusion_matrix ,accuracy_score, precision_score, recall_score, f1_score,classification_report

# %% [markdown]
# # Importance features (preprocessing)

# %%
# selecting features 

clf = RandomForestClassifier()

# Use SelectFromModel to select features based on importance
select_from_model = SelectFromModel(clf, threshold='median')  # Adjust threshold as needed
X_selected = select_from_model.fit_transform(X_train, y_train)


# Get selected feature names
selected_feature_names = x.columns[select_from_model.get_support()]
print(selected_feature_names)
# Out:
# Index(['V1', 'V3', 'V4', 'V7', 'V9', 'V10', 'V11', 'V12', 'V14', 'V16', 'V17',
#        'V18', 'V20', 'V21', 'V26'],
#       dtype='object')

# %% [markdown]
# # Training and evaluting the models

# %% [markdown]
# **Random Forset**

# %%
model= RandomForestClassifier()
model.fit(X_selected,y_train)
selected_xtest = select_from_model.transform(X_test)
y_pred = model.predict(selected_xtest)
accuracy = round(accuracy_score(y_test,y_pred),3)
f1_score = round(f1_score (y_test,y_pred),3)
precision_score = round(precision_score(y_test,y_pred),3)
recall_score =round(recall_score(y_test,y_pred),3)
print("Accuracy: ",accuracy * 100)
print("f1_score: ",f1_score * 100)
print("precision_score: ",precision_score * 100)
print("recall_score: ",recall_score * 100)
# Out:
# Accuracy:  100.0
# f1_score:  83.5
# precision_score:  97.1
# recall_score:  73.3

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56656
#            1       0.97      0.73      0.84        90
#
#     accuracy                           1.00     56746
#    macro avg       0.99      0.87      0.92     56746
# weighted avg       1.00      1.00      1.00     56746
